# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.5/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/PlantDoc-Object-Detection/yolo.zip'
extract_path = '/content/drive/MyDrive/PlantDoc-Object-Detection/dataset'

# Unzip only if not already extracted
if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print("✅ Dataset extracted to:", extract_path)
# Out:
# ✅ Dataset extracted to: /content/drive/MyDrive/PlantDoc-Object-Detection/dataset

# %%
os.listdir(extract_path)
# Out:
# ['yolo']

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8s.pt")

# %%
model.train(
    data='/content/drive/MyDrive/PlantDoc-Object-Detection/dataset.yaml',
    epochs=30,
    imgsz=416,
    batch=8,
    name='PlantDoc-Object-Detection',
    patience=20,
    verbose=True,
    augment=True
)
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.val(data="/content/drive/MyDrive/PlantDoc-Object-Detection/dataset.yaml")
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,136,807 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 73.1±36.3 MB/s, size: 165.5 KB)
# val: Scanning /content/drive/MyDrive/PlantDoc-Object-Detection/dataset/yolo/labels/test.cache... 237 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 237/237 356.3Kit/s 0.0s
# val: /content/drive/MyDrive/PlantDoc-Object-Detection/dataset/yolo/images/test/02.-Rust-2017-207u24s.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 2.8it/s 5.4s
#                    all        237        452      0.602      0.587      0.614      0.485
#            Cherry leaf         10         13      0.839      0.846      0.809      0.651
#             Peach leaf          9         10       0.45        0.9      0.752      0.584
# ...

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Dossier avec les résultats
result_folder = "/content/runs/detect/val"

# Liste les fichiers image
images = [f for f in os.listdir(result_folder) if f.endswith(('.jpg', '.png'))]

# Affiche les 5 premières images
for img_file in images[:8]:
    img_path = os.path.join(result_folder, img_file)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    plt.title(img_file)
    plt.axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
print(results.box.map)        # mAP@0.5
print(results.box.map50)      # mAP@0.5
print(results.box.map75)      # mAP@0.75
print(results.box.maps)       # mAP par classe
# Out:
# 0.484800371237143
# 0.614249868114212
# 0.5531866976946137
# [    0.65082     0.58446     0.70825     0.43853     0.39729     0.53449     0.46162     0.10079     0.57028     0.80352     0.46319      0.4848     0.26832     0.22862     0.69606     0.58382     0.68369      0.8557     0.25974     0.40259     0.18028     0.16299     0.60713     0.28883     0.39623      0.2483
#       0.4848     0.71766     0.79642]
